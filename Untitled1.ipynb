# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pySibernetic

# %%
config=pySibernetic.owConfigProperty('worm')

# %%
config.TimeLim = 10.
config.LogStep = 20 #every 1e-4 sec.
config.TimeStep = 5e-6

sim=pySibernetic.owPhysicsFluidSimulator(config)

# %%
m=pySibernetic.MuscleSimulation()
m.increment=5;

# %%
import matplotlib.animation

# %%
for i in range(25): 
        sim.simulationStep(True)
        m_t=m.run()
        sim.MuscleAtcivationSignal[:96]=m_t
        sim.pushMuscleActivity2openCLsolver()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-44802887a8d5> in <module>()
#       1 for i in range(25):
# ----> 2         sim.simulationStep(True)
#       3         m_t=m.run()
#       4         sim.MuscleAtcivationSignal[:96]=m_t
#       5         sim.pushMuscleActivity2openCLsolver()
#
# RuntimeError: Could not enqueue read data from buffer  error code is error code is -5

# %%
close()
f=figure()
ax=subplot(111)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
def anim_worm(t):
    for i in range(25): 
        sim.simulationStep(True)
        m_t=m.run()
        sim.MuscleAtcivationSignal[:96]=m_t
        sim.pushMuscleActivity2openCLsolver()
    r=sim.Position.reshape((-1,4))
    r1 = r[(r[:,3]>1.75) * (r[:,3]<2.55)  ,:3]
    ax.clear()
    s=ax.scatter(r1[0::1,2],r1[0::1,0],s=1)
    ax.set_aspect(1)
    ax.set_title("t={}".format(t))
    xlim(0,700)
    ylim(0,100)

# %%
matplotlib.animation.FuncAnimation(f,anim_worm,500)

# %%
a=_

# %%
a.
# Out:
#   File "<ipython-input-12-a0d310e2b5e6>", line 1
#     a.
#       ^
# SyntaxError: invalid syntax

# %%
while sim.Iteration<2000:
    sim.simulationStep(True)
    m_t=m.run()
    sim.MuscleAtcivationSignal[:96]=m_t
    sim.pushMuscleActivity2openCLsolver()

# %%
5
# Out:
# 5

# %%
close()
r=sim.Position.reshape((-1,4))
r1 = r[(r[:,3]>1.75) * (r[:,3]<2.55)  ,:3]
ax=subplot(111)
s=ax.scatter(r1[0::1,2],r1[0::1,0],s=1)
ax.set_aspect(1)
xlim(0,700)
ylim(0,100)

# %%
sim.Iteration
# Out:
# 25
